# %% [markdown]
# <a href="https://colab.research.google.com/github/berlin-n/Data-Exploration-with-Pandas/blob/main/Data_Exploration_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/berlin-n/Data-Exploration-with-Pandas/refs/heads/main/pokemon_data.csv'
df = pd.read_csv(url)
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name', 'Type 1', 'Type 2']][0:10]
# Out:
#                         Name Type 1  Type 2
# 0                  Bulbasaur  Grass  Poison
# 1                    Ivysaur  Grass  Poison
# 2                   Venusaur  Grass  Poison
# 3      VenusaurMega Venusaur  Grass  Poison
# 4                 Charmander   Fire     NaN
# 5                 Charmeleon   Fire     NaN
# 6                  Charizard   Fire  Flying
# 7  CharizardMega Charizard X   Fire  Dragon
# 8  CharizardMega Charizard Y   Fire  Flying
# 9                   Squirtle  Water     NaN

# %%
df.iloc[[1,4,7]]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 4       50     65           1      False
# 7       85    100           1      False

# %%
df.loc[df['Attack']< 50]
# Out:
#        #            Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur     Grass  Poison  45      49       49       65
# 9      7        Squirtle     Water     NaN  44      48       65       50
# 13    10        Caterpie       Bug     NaN  45      30       35       20
# 14    11         Metapod       Bug     NaN  50      20       55       25
# 15    12      Butterfree       Bug  Flying  60      45       50       90
# ..   ...             ...       ...     ...  ..     ...      ...      ...
# 746  678    MeowsticMale   Psychic     NaN  74      48       76       83
# 747  678  MeowsticFemale   Psychic     NaN  74      48       76       83
# 754  684         Swirlix     Fairy     NaN  62      48       66       59
# 764  694      Helioptile  Electric  Normal  44      38       33       61
# 790  714          Noibat    Flying  Dragon  40      30       35       45
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Fire'].sort_values('Attack')
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 616  555         DarmanitanZen Mode   Fire   Psychic  105      30      105
# 236  218                     Slugma   Fire       NaN   40      40       40
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 721  653                   Fennekin   Fire       NaN   40      45       40
# 237  219                   Magcargo   Fire      Rock   50      50      120
# 735  667                     Litleo   Fire    Normal   62      50       58
# 169  155                  Cyndaquil   Fire       NaN   39      52       43
# 4      4                 Charmander   Fire       NaN   39      52       43
# 572  513                    Pansear   Fire       NaN   50      53       48
# 435  390                   Chimchar   Fire       NaN   44      58       44
# 722  654                    Braixen   Fire       NaN   59      59       58
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:,4:10].sum(axis=1)

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
# To test
45+49+49+65+65+45
# Out:
# 318

# %%
cols=df.iloc[:,4:11]
df = df.drop(columns=cols)
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Total
# 0      1              Bulbasaur    Grass  Poison      False    318
# 1      2                Ivysaur    Grass  Poison      False    405
# 2      3               Venusaur    Grass  Poison      False    525
# 3      3  VenusaurMega Venusaur    Grass  Poison      False    625
# 4      4             Charmander     Fire     NaN      False    309
# ..   ...                    ...      ...     ...        ...    ...
# 795  719                Diancie     Rock   Fairy       True    600
# 796  719    DiancieMega Diancie     Rock   Fairy       True    700
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True    600
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True    680
# 799  721              Volcanion     Fire   Water       True    600
#
# [800 rows x 6 columns]

# %%
df = df[['Name', 'Total', 'Type 1', 'Type 2', 'Legendary']]
df
# Out:
#                       Name  Total   Type 1  Type 2  Legendary
# 0                Bulbasaur    318    Grass  Poison      False
# 1                  Ivysaur    405    Grass  Poison      False
# 2                 Venusaur    525    Grass  Poison      False
# 3    VenusaurMega Venusaur    625    Grass  Poison      False
# 4               Charmander    309     Fire     NaN      False
# ..                     ...    ...      ...     ...        ...
# 795                Diancie    600     Rock   Fairy       True
# 796    DiancieMega Diancie    700     Rock   Fairy       True
# 797    HoopaHoopa Confined    600  Psychic   Ghost       True
# 798     HoopaHoopa Unbound    680  Psychic    Dark       True
# 799              Volcanion    600     Fire   Water       True
#
# [800 rows x 5 columns]
